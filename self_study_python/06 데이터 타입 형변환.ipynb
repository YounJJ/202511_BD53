# %%
# string
text = "Hello Python"
len(text)
# Out:
# 12

# %%
# list, tuple
ls = [1, 2, 3, 4, 5]
len(ls)
# Out:
# 5

# %%
dic = {
    0 : "easyupclass", 1:"python"
}
len(dic)
# Out:
# 2

# %%
a = 123 # 숫자형은 len 함수가 오류나옴
len(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 a = 123
# ----> 2 len(a)
#
# TypeError: object of type 'int' has no len()

# %%
# Boolean
True, False
# Out:
# (True, False)

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
float(False)
# Out:
# 0.0

# %%
ls = [1, 2, 3]
tuple(ls), type(tuple(ls))
# Out:
# ((1, 2, 3), tuple)

# %%
dic.values()
# Out:
# dict_values(['easyupclass', 'python'])

# %%
type(dic.values())
# Out:
# dict_values

# %%
list(dic.values()), type(list(dic.values()))
# Out:
# (['easyupclass', 'python'], list)

# %%
ls1 = [0, 1, 2, 3]
ls2 = ["python", "r", "sql", "java"]

# %%
zip(ls1, ls2)

# %%
list(zip(ls1, ls2))
# Out:
# [(0, 'python'), (1, 'r'), (2, 'sql'), (3, 'java')]

# %%
dict(zip(ls1, ls2))
# Out:
# {0: 'python', 1: 'r', 2: 'sql', 3: 'java'}

# %%
ls3 = [["python", "easy"], ["r", "complex"], ["slq", "easy"], ["java", ""]]
dict(zip(ls1, ls3))
# Out:
# {0: ['python', 'easy'],
#  1: ['r', 'complex'],
#  2: ['slq', 'easy'],
#  3: ['java', '']}
