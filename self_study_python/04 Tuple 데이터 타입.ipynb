# %%
tp1 = 1, 2, 3
tp2 = (4, 5, 6)
type(tp1), type(tp2), tp1, tp2
# Out:
# (tuple, tuple, (1, 2, 3), (4, 5, 6))

# %%
a, b = "python", "hello"
a, b
# Out:
# <class 'str'> <class 'str'>

# %%
print(a)
print(b)
# Out:
# python
# hello

# %%
type(a)
# Out:
# str

# %%
tp1[1], tp2[0:2]
# Out:
# (2, (4, 5))

# %%
# 카드 포인트 적립
# rate = 0.003
rate = (0, 0.003)
print(rate)
# Out:
# (0, 0.003)

# %%
card = 100_000
point = (card, rate)
print(point)
# Out:
# (100000, (0, 0.003))

# %%
point_cal = point[0] * point[1][1]
point_cal
# Out:
# 300.0

# %%
rate[1] = 0.3
rate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 rate[1] = 0.3
#       2 rate
#
# TypeError: 'tuple' object does not support item assignment
