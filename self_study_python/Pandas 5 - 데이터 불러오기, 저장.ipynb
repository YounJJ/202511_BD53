# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 데이터 불러오기
#
# *   Pandas 패키지 안에는 csv파일 외에 다양한 파일을 불러올 수 있습니다.
# *   csv파일을 DataFrame으로 생성하기 위해서는 column명과 index가 존재하면 좋음

# %% [markdown]
# ## 현재 위치 확인

# %%
import pandas as pd
import numpy as np

# %%
# %pwd
# Out:
# '/content'

# %%
sample = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/train.csv")
sample
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(sample)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## header parameter

# %%
sample2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/train.csv", header = None)
sample2
# Out:
#               0         1       2   \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                     3       4    5      6   \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %% [markdown]
# ### header = None 설정 후 names 생성

# %%
sample.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
col_list = list(sample.columns)
col_list
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
sample2_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/train.csv", header = None, names = col_list)
sample2_2
# Out:
#      PassengerId  Survived  Pclass  \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %% [markdown]
# ## encoding parameter

# %%
sample_text = pd.read.csv("./datas/sample_text.csv", encoding = 'ansi')
# 저장된 파일이 ansi 형태로 encoding 되어 있다면 지정해줘야 정상적으로 불러와짐
sample_text = pd.read.csv("./datas/sample_text.csv", encoding = 'utf-8')
# 이거는 에러가 남.

# %% [markdown]
# ## index_col 설정

# %%
sample4 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/train.csv", index_col = "PassengerId")
sample4
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### save

# %%
sample.to_csv("/content/drive/MyDrive/Colab Notebooks/titanic.csv", sep = "\t", index = False)
