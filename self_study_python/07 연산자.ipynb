# %%
8//4 # 몫을 의미함
# Out:
# 2

# %%
8 % 5 # 나머지를 의미함
# Out:
# 3

# %%
2 ** 8 # 제곱을 의미함
# Out:
# 256

# %%
a = 100
a = a * 1.1
a = a * 1.1
a
# Out:
# 121.00000000000003

# %%
b = 100
b *= 1.1
b *= 1.1
b
# Out:
# 121.00000000000003

# %%
c = 256
c /= 2
c /= 2
c /= 2
c
# Out:
# 32.0

# %% [markdown]
# ### 비교
#     >, <, >=, <=, ==, !=
#     결과값이 True, False

# %%
d = 5
e = 5.0
d == e
# Out:
# True

# %%
d != e
# Out:
# False

# %% [markdown]
# ### 논리
#     and, or, not
#     True, False로 나타내는 연산
#     연산은 앞에서부터 순서대로 진행

# %%
True and False, True or False, False and False, not True and False
# Out:
# (False, True, False, False)

# %% [markdown]
# ### 멤버
#     in, not in
#     특정 데이터가 있는지 확인할 때 사용

# %%
ls = ['easy', 'up', 'class', 'python']
'easy' in ls, 'down' in ls, 'subject' not in ls, 'R' not in ls
# Out:
# (True, False, True, True)
