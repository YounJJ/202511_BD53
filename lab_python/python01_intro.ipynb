# %% [markdown]
# # Colab 소개

# %%
print('Hello!')
# Out:
# Hello!

# %% [markdown]
# Colab 코드 셀 실행 방법:
#
#
# *   실행 버튼 클릭
# *   런타임 메뉴에서 실행과 관련된 항목을 선택
# *   단축키
#     *  Ctrl+Enter: 현재 포커스(초점)이 있는 셀을 실행
#     *  Shift+Enter: 현재 포커스가 있는 셀을 실행하고, 그 다음 셀로 포커스를 이동. 만약 다음 셀이 없으면 새로운 코드 셀을 자동으로 만들어 줌.
#     *  Ctrl+F9: 모두 실행. Jupyter 노트북의 모든 코드 셀들을 처음부터 순서대로 실행.
#     *  Ctrl+F10: 셀 및 하위 셀 실행. 현재 포커스가 있는 셀부터 노트북 마지막의 코드 셀까지 순서대로 실행.
#     *  Ctrl+F8: 이전 셀 실행. 현재 포커스가 있는 셀의 이전 코드 셀들을 처음부터 순서대로 실행.

# %%
print('안녕, 파이썬!')
# Out:
# 안녕, 파이썬!

# %% [markdown]
# # Python 버전 확인

# %%
import sys  # sys 모듈을 임포트(사용)

print(sys.version) # 설치된 파이썬 버전을 출력
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# # 여러가지 print 방법

# %%
# 인라인 주석(inline comment)
# 파이썬 문장은 문장 끝에 세미콜론(;)을 사용하지 않음.
# 파이썬은 문자열(string)은 작은따옴표('')와 큰따옴표("")를 모두 사용 가능.
# 파이썬의 식별자(예약어, 함수이름)들은 대/소문자를 구분.

print('안녕하세요!!')
print("Hello!!")
print("I'm a boy.")
print('I\'m a boy.')
# Out:
# 안녕하세요!!
# Hello!!
# I'm a boy.
# I'm a boy.

# %%
print('Hello', '안녕하세요', 'Bon Jour')
# 출력할 문자열들이 쉼표로 구분되서 여러개가 있는 경우,
# 문자열과 문자열을 공백으로 구분해서 한 줄에 출력
# Out:
# Hello 안녕하세요 Bon Jour

# %%
x = 100  # 변수 x에 100을 할당(저장)
y = 15

print(x, y)
print (x, '+', y, '=', x + y)
print(f'{x} - {y} = {x - y}')  # f-string(formatted string): 파이썬 버전 3.6 이상.
print(f'{x} x {y} = {x * y}')
print(f'{x} / {y} = {x / y}')
# Out:
# 100 15
# 100 + 15 = 115
# 100 - 15 = 85
# 100 x 15 = 1500
# 100 / 15 = 6.666666666666667

# %% [markdown]
# 사용자 입력(키보드 입력)을 출력

# %%
name = input('이름을 입력하세요.')
print(name)
# Out:
# 이름을 입력하세요.Scott tiger
# Scott tiger
